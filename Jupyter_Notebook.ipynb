# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ### NOTEBOOK TITLE

# %% [markdown]
# Introduction to the notebook

# %% [markdown]
# List of data science languages
#
# Python
# R
# SQL
# Julia
# Scala
# SAS
# MATLAB
# Java
# C++
# Perl

# %% [markdown]
# Libraries:
#
#
# Python:
# NumPy
# pandas
# scikit-learn
# TensorFlow
# Keras
# PyTorch
# Matplotlib
# Seaborn
# Plotly
# NLTK
#
#
# R:
# ggplot2
# dplyr
# tidyr
# caret
# data.table
# shiny
# randomForest
# Rcpp
# stringr
# lubridate

# %% [markdown]
# | Language     | Libraries/Frameworks  | Tools/Platforms  |
# |--------------|-----------------------|------------------|
# | Python       | NumPy, pandas,        | Jupyter Notebook,|
# |              | scikit-learn,         | Anaconda,        |
# |              | TensorFlow, Keras,    | PyCharm,         |
# |              | PyTorch, Matplotlib,  | Spyder           |
# |              | Seaborn, Plotly, NLTK |                  |
# | R            | ggplot2, dplyr,       | RStudio,         |
# |              | tidyr, caret,         | Shiny,           |
# |              | data.table,           | Knitr,           |
# |              | randomForest, Rcpp,   | R Markdown       |
# |              | stringr, lubridate    |                  |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Arithmetic expressions are fundamental in mathematics and programming. They involve mathematical operations such as addition, subtraction, multiplication, and division. In this section, we will explore some basic arithmetic expression examples.
#
# ### Addition
#
# To perform addition, you can use the `+` operator. Here's an example:
#
# ```python
# x = 5
# y = 3
# result = x + y
# print(result)  # Output: 8

# %%
# Multiply and Add Numbers
x = 5
y = 3

# Multiply
result_multiply = x * y
print("Multiplication Result:", result_multiply)

# Add
result_add = x + y
print("Addition Result:", result_add)
# Out:
# Multiplication Result: 15
# Addition Result: 8

# %%
# Convert Minutes to Hours
minutes = 150

# Calculate hours
hours = minutes / 60

print("Minutes:", minutes)
print("Hours:", hours)
# Out:
# Minutes: 150
# Hours: 2.5

# %% [markdown]
# ## Objectives
#
# In this exercise, our main objectives are as follows:
#
# 1. Convert minutes to hours.
# 2. Perform basic arithmetic calculations.
# 3. Demonstrate the use of variables in Python.
# 4. Practice printing output using the `print` statement.
# 5. Gain familiarity with Jupyter Notebook cells and Markdown formatting.
#
# By completing this exercise, you will strengthen your understanding of converting units of time, performing arithmetic operations, and working with Jupyter Notebook features.
#
# Let's get started!

# %% [markdown]
# ## Author
#
# This exercise was prepared by Clement.
